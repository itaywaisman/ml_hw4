# %%
#model = kmeans

# %%
#from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
#lda = LinearDiscriminantAnalysis(n_components=5)
#X_r2 = lda.fit(df, kmeans.labels_).transform(df)

#X_r2

# %%
import pandas as pd
import numpy as np
import pickle
from scipy import stats

# %%
df = pd.read_csv('data/protein.csv')

# %%
id_col = df['ID']

# %% [markdown]
# # Data preperation

# %%
df = df.drop(labels=['ID'], axis=1)

# %%
df.dtypes
# Out:
# protein_1     float64
# protein_2     float64
# protein_3     float64
# protein_4     float64
# protein_5     float64
# protein_6     float64
# protein_7     float64
# protein_8     float64
# protein_9     float64
# protein_10    float64
# dtype: object

# %%
class OutlierClipper:
    def __init__(self, features, threshold = 1.5):
        self.threshold = threshold
        self._features = features
        self._feature_map = {}

    def fit(self, X, **kwargs):
        df = X[self._features]
        features = list(df.columns)
        for feature in features:
            # f_q1 = df[feature].quantile(0.25)
            # f_q3 = df[feature].quantile(0.75)
            # f_iqr = f_q3 - f_q1

            mean = X[feature].mean()
            std = X[feature].std(ddof=0)
            
            self._feature_map[feature] = (mean - (self.threshold * std), mean + (self.threshold * std))
        return self
    
    def count_outliers(self, data):
        for column in data.columns:
            too_low = sum(data[column] < self._feature_map[column][0])
            too_high = sum(data[column] > self._feature_map[column][1])
            print('Column {} has {} high values and {} low values. overall: {}'.format(column, too_high, too_low, too_high + too_low))

    def transform(self, data):
        data_copy = data.copy()
        for feature in self._feature_map.keys():
            data_copy[feature] = data_copy[feature].clip(lower=self._feature_map[feature][0],
                                                         upper=self._feature_map[feature][1])
        return data_copy

    def fit_transform(self, X, **kwargs):
        self.fit(X, y, **kwargs)
        return self.transform(X)

# %%
outlier_clipper = OutlierClipper(df.columns, threshold=1)
outlier_clipper.fit(df)
df = outlier_clipper.transform(df)

# %%
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer


class Imputer:
    def __init__(self):
        self.iterative_imputer = IterativeImputer(initial_strategy='mean')

    def fit(self, X, **kargs):
        self.iterative_imputer.fit(X)
        # print(X.shape)
        return self

    def transform(self, X):
        columns = X.columns
        X = self.iterative_imputer.transform(X)
        X = pd.DataFrame(X, columns=columns)
        return X

    def fit_transform(self, X, **kwargs):
        self.fit(X, y, **kwargs)
        return self.transform(X)

# %%
imputer = Imputer()
imputer.fit(df)
df = imputer.transform(df)
df.isna().sum()
# Out:
# protein_1     0
# protein_2     0
# protein_3     0
# protein_4     0
# protein_5     0
# protein_6     0
# protein_7     0
# protein_8     0
# protein_9     0
# protein_10    0
# dtype: int64

# %%
df.describe()
# Out:
#         protein_1   protein_2   protein_3   protein_4   protein_5   protein_6  \
# count  494.000000  494.000000  494.000000  494.000000  494.000000  494.000000
# mean    -0.113080   -0.178289    0.054462    1.054271    0.081684   -0.168656
# std      1.610126    2.900357    1.637812    3.454395    2.320824    2.546993
# min     -6.988484  -21.059248   -8.281800  -15.793730   -3.439964  -11.080775
# 25%     -1.000435   -0.908684   -0.649152   -2.044648   -1.663794   -1.690087
# 50%     -0.303210   -0.213589    0.095605    1.640231   -0.303521   -0.625816
# 75%      0.540866    0.465710    0.811024    3.448381    2.140752    1.125899
# max      6.064229   18.711459    7.827003   18.724884    3.689852    9.595209
#
#         protein_7   protein_8   protein_9  protein_10
# count  494.000000  494.000000  494.000000  494.000000
# mean     0.056921   -0.045867   -0.107584    0.033990
# std      1.587216    1.144313    2.262344    0.857679
# min     -5.325755   -4.606367  -14.695770   -1.514069
# 25%     -0.783157   -0.769140   -1.002541   -0.619832
# 50%     -0.100479   -0.083797    0.031503    0.039066
# 75%      0.722525    0.645523    0.835537    0.628403
# max      6.049897    4.206154   12.848736    1.807004

# %% [markdown]
# # Model training

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import davies_bouldin_score, make_scorer
from sklearn.metrics import silhouette_score
from sklearn.model_selection import GridSearchCV, cross_val_score

# %%
kmeans = KMeans(n_clusters=5, max_iter=500, n_init=30)

spectral = SpectralClustering(n_clusters=5,
        n_components=6,
        gamma=100,
        assign_labels="discretize")

gmm = GaussianMixture(n_components=5)

# %%
kmeans.fit(df)
spectral.fit(df)
gmm.fit(df)
# Out:
# C:\Users\itayw\anaconda3\envs\ml-hw2\lib\site-packages\sklearn\manifold\_spectral_embedding.py:236: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# GaussianMixture(n_components=5)

# %% [markdown]
# ## Scores

# %%
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import silhouette_score

print(f'KMEANS davies_boulding: {davies_bouldin_score(df, kmeans.labels_)}')
print(f'SPECTRAL davies_boulding: {davies_bouldin_score(df, spectral.labels_)}')
print(f'GNN davies_boulding: {davies_bouldin_score(df, gmm.predict(df))}')

print('------------------------------------')

print(f'KMEANS silhouette_score: {silhouette_score(df, kmeans.labels_)}')
print(f'SPECTRAL silhouette_score: {silhouette_score(df, spectral.labels_)}')
print(f'GNN silhouette_score: {silhouette_score(df, gmm.predict(df))}')
# Out:
# KMEANS davies_boulding: 1.3126485827854544
# SPECTRAL davies_boulding: 14.034399757310249
# GNN davies_boulding: 2.1626187113991966
# ------------------------------------
# KMEANS silhouette_score: 0.26111124912275385
# SPECTRAL silhouette_score: -0.1481331642973831
# GNN silhouette_score: 0.1981922203259694

# %% [markdown]
# # Select most useful features

# %%
def print_score(features):
    k = KMeans(n_clusters=5, max_iter=500, n_init=30)

    features = [f'protein_{i}' for i in features]


    k_fitted = k.fit(df[features])

    y = k_fitted.predict(df[features])

    print(f'davies_bouldin_score: {davies_bouldin_score(df, y)}')
    print(f'silhouette_score: {silhouette_score(df, y)}')

# %% [markdown]
# ## By single feature score reduction

# %%
feature_scores = []
kmeans = KMeans(n_clusters=5, max_iter=500, n_init=30)
kmeans_temp = kmeans.fit(df)
print('Base score: {}'.format(silhouette_score(df, kmeans.labels_)))
for i in range(10):
    column = f'protein_{i+1}'
    df_temp = df.drop([column], axis=1)
    kmeans = KMeans(n_clusters=5, max_iter=500, n_init=30, random_state=0)
    kmeans_temp = kmeans.fit(df_temp)
    feature_scores.append(silhouette_score(df, kmeans_temp.labels_))
    
importance = pd.DataFrame(feature_scores)
importance.index = np.arange(1, len(importance) + 1)
print(importance)
best_5 = importance[0].nlargest(5).index.to_numpy()
print(best_5)

print_score(best_5)
# Out:
# Base score: 0.25653616514832067
#            0
# 1   0.257265
# 2   0.253344
# 3   0.254429
# 4   0.181034
# 5   0.234241
# 6   0.248263
# 7   0.261376
# 8   0.254258
# 9   0.255135
# 10  0.261184
# [ 7 10  1  9  3]
# davies_bouldin_score: 2.1787856460336705
# silhouette_score: 0.11226123610510659

# %% [markdown]
# ## By feature set

# %%
from itertools import combinations

def get_feature_scores(df, models, score_fn):
    feature_scores = pd.DataFrame()
    for column_subset in combinations(df.columns, 5):
        df_temp = df[list(column_subset)]
        scores = []
        for model in models:
            fitted_model = model.fit(df_temp)
            scores.append(score_fn(df, fitted_model.predict(df_temp)))
        print(f'.', end =" ")
        feature_scores[','.join(column_subset)] = scores
    return feature_scores.T

# kmeans = KMeans(n_clusters=5, max_iter=500, n_init=30)

models = [KMeans(n_clusters=5, max_iter=500, n_init=30),
          GaussianMixture(n_components=5)]

n_iter = 6

print('Iteration #1')
total_scores = get_feature_scores(df, models, silhouette_score)

for i in range(n_iter-1):
    print(f'Iteration #{i+2}')
    scores_df = get_feature_scores(df, models, silhouette_score)
    total_scores = total_scores + scores_df
    
avg_scores = total_scores / 6
avg_scores = avg_scores
avg_scores = avg_scores.rename(columns={"0": "KMEANS", "B": "GMM"})

print(avg_scores['KMEANS'].idxmax())
print(avg_scores['GMM'].idxmax())
# Out:
# Iteration #1
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_5') got scores [0.23985090785709734, 0.20597531640116323]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_6') got scores [0.23975552314839377, 0.22595070853524216]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_7') got scores [0.1872572909695991, 0.20833153029811668]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_8') got scores [0.1865694406561689, 0.194675768712521]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_9') got scores [0.24714796418786383, 0.21725782179569395]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_10') got scores [0.16614417788476343, 0.2130481575601765]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_5', 'protein_6') got scores [0.17116337259706255, 0.12182668399036463]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_5', 'protein_7') got scores [0.15996055275510654, 0.13288140028955156]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_5', 'protein_8') got scores [0.15093050447857226, 0.11753910752469578]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_5', 'protein_9') got scores [0.16575959262981915, 0.11720295156335718]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_5', 'protein_10') got scores [0.159870743181689, 0.13886301079106786]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_6', 'protein_7') got scores [0.11013062157089507, 0.13323956306422086]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_6', 'protein_8') got scores [0.10125477105925182, 0.11783714769445738]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_6', 'protein_9') got scores [0.1593676899408031, 0.14601995202823326]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_6', 'protein_10') got scores [0.09088816856486312, 0.1632006470554528]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_7', 'protein_8') got scores [0.10115650228647002, 0.05854616705583673]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_7', 'protein_9') got scores [0.1043117310500467, 0.06280301627306936]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_7', 'protein_10') got scores [0.0825932470271027, 0.09654509705250007]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_8', 'protein_9') got scores [0.09355027640460846, 0.08562514618161492]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_8', 'protein_10') got scores [0.10867437696693381, 0.11004463876217539]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_9', 'protein_10') got scores [0.11259317133182617, 0.17236103121271631]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_5', 'protein_6') got scores [0.25497237853226495, 0.22118412681069027]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_5', 'protein_7') got scores [0.23992350346790883, 0.2195988772014491]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_5', 'protein_8') got scores [0.2398159404366225, 0.21954891390846654]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_5', 'protein_9') got scores [0.2458713489524885, 0.2260315597836209]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_5', 'protein_10') got scores [0.2404674530986983, 0.21994221626391616]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_6', 'protein_7') got scores [0.23587590401377145, 0.2026377449220776]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_6', 'protein_8') got scores [0.23702136929491838, 0.22020411972877915]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_6', 'protein_9') got scores [0.2323119557735112, 0.23071448078413948]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_6', 'protein_10') got scores [0.235272114508652, 0.22130151851788352]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_7', 'protein_8') got scores [0.17872179139286362, 0.2034131259619407]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_7', 'protein_9') got scores [0.18737044884827314, 0.2219670584798079]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_7', 'protein_10') got scores [0.17364049583962118, 0.19758357935046703]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_8', 'protein_9') got scores [0.2475365543989072, 0.22037330600038266]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_8', 'protein_10') got scores [0.1860393318484228, 0.22754268460293564]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_9', 'protein_10') got scores [0.2441692210613568, 0.22176811116130274]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_6', 'protein_7') got scores [0.16989824677002066, 0.1305500588986303]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_6', 'protein_8') got scores [0.17690756596025822, 0.140928483966748]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_6', 'protein_9') got scores [0.18076706853627195, 0.12939385265414347]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_6', 'protein_10') got scores [0.17427333642787304, 0.1348251158877241]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_7', 'protein_8') got scores [0.1579824448027895, 0.12372347771977552]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_7', 'protein_9') got scores [0.16684052087544715, 0.13582145515242522]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_7', 'protein_10') got scores [0.1603987492143699, 0.12420948108089788]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_8', 'protein_9') got scores [0.16420049911196802, 0.13201868951366055]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_8', 'protein_10') got scores [0.15048384773026574, 0.12714845533636976]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_9', 'protein_10') got scores [0.1658442977320461, 0.13044273603029433]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_7', 'protein_8') got scores [0.13339375768597178, 0.1672552913886303]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_7', 'protein_9') got scores [0.15827019146638321, 0.13161779173389668]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_7', 'protein_10') got scores [0.13254775087119564, 0.11712568918920697]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_8', 'protein_9') got scores [0.16380859947831727, 0.21331477049398853]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_8', 'protein_10') got scores [0.15603663107918236, 0.13422534928625682]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_9', 'protein_10') got scores [0.16279405943416242, 0.13984704531181683]
# subset ('protein_1', 'protein_2', 'protein_7', 'protein_8', 'protein_9') got scores [0.08183630338516845, 0.20034879416378495]
# subset ('protein_1', 'protein_2', 'protein_7', 'protein_8', 'protein_10') got scores [0.07824078586497961, 0.18121570830008163]
# subset ('protein_1', 'protein_2', 'protein_7', 'protein_9', 'protein_10') got scores [0.08721608265873047, 0.12504684596796603]
# subset ('protein_1', 'protein_2', 'protein_8', 'protein_9', 'protein_10') got scores [0.10289111432321796, 0.23307262515949742]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_5', 'protein_6') got scores [0.24860124125264638, 0.20757895529332968]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_5', 'protein_7') got scores [0.22635990909952725, 0.20884102773673102]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_5', 'protein_8') got scores [0.23537584379459928, 0.19384810454890497]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_5', 'protein_9') got scores [0.23978159404227023, 0.20471915177742317]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_5', 'protein_10') got scores [0.2263475002640512, 0.19878856390506539]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_6', 'protein_7') got scores [0.1953727413172443, 0.19437155017359775]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_6', 'protein_8') got scores [0.20321755594528793, 0.19716073336853687]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_6', 'protein_9') got scores [0.21302407875187823, 0.19365443788481213]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_6', 'protein_10') got scores [0.21045669896264116, 0.20091035398856802]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_7', 'protein_8') got scores [0.15695654044856586, 0.1616200013175461]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_7', 'protein_9') got scores [0.18474600729348833, 0.1223313788455244]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_7', 'protein_10') got scores [0.15060293500508026, 0.1197266736245129]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_8', 'protein_9') got scores [0.18674506226393728, 0.17266178690387962]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_8', 'protein_10') got scores [0.172534452766821, 0.17977704312622245]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_9', 'protein_10') got scores [0.17490719560755985, 0.17857470291533442]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_6', 'protein_7') got scores [0.16535722742219414, 0.14032852369745596]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_6', 'protein_8') got scores [0.17595984813156448, 0.1295197877894964]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_6', 'protein_9') got scores [0.15564659236767756, 0.12368552867620884]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_6', 'protein_10') got scores [0.1596563089945434, 0.1531994461256816]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_7', 'protein_8') got scores [0.14272557854982565, 0.13690644360840734]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_7', 'protein_9') got scores [0.15232075042841994, 0.1264113198715137]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_7', 'protein_10') got scores [0.14792409735005105, 0.10834305748143525]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_8', 'protein_9') got scores [0.14539456106342066, 0.1173692230881689]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_8', 'protein_10') got scores [0.13193364131545737, 0.11125599364241347]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_9', 'protein_10') got scores [0.14967986866211844, 0.1396813290578981]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_7', 'protein_8') got scores [0.12011927099645944, 0.12410351058585348]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_7', 'protein_9') got scores [0.12378722433391831, 0.14329108043079378]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_7', 'protein_10') got scores [0.11380958937503642, 0.06440102027839954]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_8', 'protein_9') got scores [0.11577524468200422, 0.12758353470985198]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_8', 'protein_10') got scores [0.08500478781701065, 0.08296734502809634]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_9', 'protein_10') got scores [0.1091412836433512, 0.15398391927938615]
# subset ('protein_1', 'protein_3', 'protein_7', 'protein_8', 'protein_9') got scores [0.10214738740481442, 0.07579626590788821]
# subset ('protein_1', 'protein_3', 'protein_7', 'protein_8', 'protein_10') got scores [0.06632158242563847, 0.03937956841348438]
# subset ('protein_1', 'protein_3', 'protein_7', 'protein_9', 'protein_10') got scores [0.10820036732482122, 0.08647011840588284]
# subset ('protein_1', 'protein_3', 'protein_8', 'protein_9', 'protein_10') got scores [0.11951151267440038, 0.09764694941404868]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_6', 'protein_7') got scores [0.2483691474034796, 0.21179921891543946]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_6', 'protein_8') got scores [0.2479612571262793, 0.20807430124811857]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_6', 'protein_9') got scores [0.2553416287860282, 0.20426216066328573]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_6', 'protein_10') got scores [0.24822402591393983, 0.18230601113642314]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_7', 'protein_8') got scores [0.22996056830460634, 0.21511155822030734]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_7', 'protein_9') got scores [0.2403967658742002, 0.20096643172725773]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_7', 'protein_10') got scores [0.22154642178152417, 0.20559020795822472]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_8', 'protein_9') got scores [0.24202366114793816, 0.21996498565558356]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_8', 'protein_10') got scores [0.22980520912965258, 0.21106591351960585]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_9', 'protein_10') got scores [0.23918415701960727, 0.22455349003409278]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_7', 'protein_8') got scores [0.18868876749703706, 0.19542170279964288]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_7', 'protein_9') got scores [0.22343148912988783, 0.19887204449096857]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_7', 'protein_10') got scores [0.19214238648078205, 0.1273479501515313]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_8', 'protein_9') got scores [0.21113948306696875, 0.19219979875484652]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_8', 'protein_10') got scores [0.19011066372465987, 0.19036037766926195]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_9', 'protein_10') got scores [0.21013205571394114, 0.15902330837506112]
# subset ('protein_1', 'protein_4', 'protein_7', 'protein_8', 'protein_9') got scores [0.18797919826195267, 0.19976394045917184]
# subset ('protein_1', 'protein_4', 'protein_7', 'protein_8', 'protein_10') got scores [0.17787356361838977, 0.15971529227195538]
# subset ('protein_1', 'protein_4', 'protein_7', 'protein_9', 'protein_10') got scores [0.18530344849456762, 0.1282228130529576]
# subset ('protein_1', 'protein_4', 'protein_8', 'protein_9', 'protein_10') got scores [0.18937770626256165, 0.17140225461826947]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_7', 'protein_8') got scores [0.17346370196081318, 0.11454664411036801]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_7', 'protein_9') got scores [0.15616995615499016, 0.12406001029313762]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_7', 'protein_10') got scores [0.16838455844927988, 0.10999872332418983]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_8', 'protein_9') got scores [0.1597163657593044, 0.17438156093864052]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_8', 'protein_10') got scores [0.16805062813711202, 0.16197674549869284]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_9', 'protein_10') got scores [0.16087019727033128, 0.13130237602910802]
# subset ('protein_1', 'protein_5', 'protein_7', 'protein_8', 'protein_9') got scores [0.15257169257452735, 0.12170050552646515]
# subset ('protein_1', 'protein_5', 'protein_7', 'protein_8', 'protein_10') got scores [0.13523111619583816, 0.1386431617763993]
# subset ('protein_1', 'protein_5', 'protein_7', 'protein_9', 'protein_10') got scores [0.1574534812379113, 0.13477411050806315]
# subset ('protein_1', 'protein_5', 'protein_8', 'protein_9', 'protein_10') got scores [0.14719387916904436, 0.09744734907778209]
# subset ('protein_1', 'protein_6', 'protein_7', 'protein_8', 'protein_9') got scores [0.12834371411226536, 0.11145927167565958]
# subset ('protein_1', 'protein_6', 'protein_7', 'protein_8', 'protein_10') got scores [0.1080418756895169, 0.10207877731415578]
# subset ('protein_1', 'protein_6', 'protein_7', 'protein_9', 'protein_10') got scores [0.12852620875273044, 0.10674768402728053]
# subset ('protein_1', 'protein_6', 'protein_8', 'protein_9', 'protein_10') got scores [0.12534908149435503, 0.1531679998759174]
# subset ('protein_1', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.10916064415571185, 0.09430345111022058]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_5', 'protein_6') got scores [0.2509827730124911, 0.22396974979286288]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_5', 'protein_7') got scores [0.2397006289315529, 0.22901682419566005]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_5', 'protein_8') got scores [0.24018447243066876, 0.20657335558076334]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_5', 'protein_9') got scores [0.24931509627517046, 0.22891301662460625]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_5', 'protein_10') got scores [0.24035976962084737, 0.21812322603099038]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_6', 'protein_7') got scores [0.23652053323382036, 0.17066890176516847]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_6', 'protein_8') got scores [0.23781516063045488, 0.21058001019209888]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_6', 'protein_9') got scores [0.24110437179897487, 0.1821269341724833]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_6', 'protein_10') got scores [0.23817636966649386, 0.18584574547469263]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_7', 'protein_8') got scores [0.18087724603787597, 0.1939787483004129]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_7', 'protein_9') got scores [0.24740006139842813, 0.2303641496793996]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_7', 'protein_10') got scores [0.1769382192398434, 0.21037348918583362]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_8', 'protein_9') got scores [0.1981802004143409, 0.22556898958951394]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_8', 'protein_10') got scores [0.1894181410037348, 0.17326575119086823]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_9', 'protein_10') got scores [0.19903474501410917, 0.23843089369886203]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_6', 'protein_7') got scores [0.17646387797570304, 0.14092228892168776]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_6', 'protein_8') got scores [0.17495423577228775, 0.15107258219094466]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_6', 'protein_9') got scores [0.1805118016489871, 0.16008842655636096]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_6', 'protein_10') got scores [0.17425335942874196, 0.14420315646132134]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_7', 'protein_8') got scores [0.1476039765702626, 0.1507963611953402]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_7', 'protein_9') got scores [0.16705741232941737, 0.13987794874875117]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_7', 'protein_10') got scores [0.1456660963773353, 0.1299821893172927]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_8', 'protein_9') got scores [0.16298503221742336, 0.12078220663742485]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_8', 'protein_10') got scores [0.1692831786032191, 0.1411490996750268]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_9', 'protein_10') got scores [0.16554071720642363, 0.10291734183527049]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_7', 'protein_8') got scores [0.12742907273992862, 0.10718023694451453]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_7', 'protein_9') got scores [0.16886297830609803, 0.14720718299012153]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_7', 'protein_10') got scores [0.13730011649243448, 0.1241006459957514]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_8', 'protein_9') got scores [0.16125284469368514, 0.1540191799139459]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_8', 'protein_10') got scores [0.09963862232706269, 0.09710957120144724]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_9', 'protein_10') got scores [0.16009664681736502, 0.14617699907305923]
# subset ('protein_2', 'protein_3', 'protein_7', 'protein_8', 'protein_9') got scores [0.08180280644759655, 0.09443553979171676]
# subset ('protein_2', 'protein_3', 'protein_7', 'protein_8', 'protein_10') got scores [0.06694179604603467, 0.05472491489008461]
# subset ('protein_2', 'protein_3', 'protein_7', 'protein_9', 'protein_10') got scores [0.3306151678285686, 0.22257925258944544]
# subset ('protein_2', 'protein_3', 'protein_8', 'protein_9', 'protein_10') got scores [0.2989889613291057, 0.08023031718364344]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_6', 'protein_7') got scores [0.2511753675356131, 0.22400012057996146]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_6', 'protein_8') got scores [0.2517787268068294, 0.21813414705340503]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_6', 'protein_9') got scores [0.25587880586696227, 0.21624629872364423]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_6', 'protein_10') got scores [0.25195836342213995, 0.22526508509598053]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_7', 'protein_8') got scores [0.2397006289315529, 0.2186017120448733]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_7', 'protein_9') got scores [0.249566504266212, 0.23504073858244895]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_7', 'protein_10') got scores [0.24035976962084737, 0.2262983636027378]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_8', 'protein_9') got scores [0.250431979267599, 0.23426597846053684]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_8', 'protein_10') got scores [0.24000184110884906, 0.22071311473375316]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_9', 'protein_10') got scores [0.24961389494079403, 0.23358229575283013]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_7', 'protein_8') got scores [0.23630129775984487, 0.2155991663952405]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_7', 'protein_9') got scores [0.2345615337724877, 0.21110877148511617]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_7', 'protein_10') got scores [0.23273094447694342, 0.22320577882550244]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_8', 'protein_9') got scores [0.21202944173887986, 0.2203842056351621]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_8', 'protein_10') got scores [0.23780565134037146, 0.2029419880386982]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_9', 'protein_10') got scores [0.23345632403658942, 0.23448321407827297]
# subset ('protein_2', 'protein_4', 'protein_7', 'protein_8', 'protein_9') got scores [0.2009254695367729, 0.22595701467002266]
# subset ('protein_2', 'protein_4', 'protein_7', 'protein_8', 'protein_10') got scores [0.1844122995294177, 0.1572186306135935]
# subset ('protein_2', 'protein_4', 'protein_7', 'protein_9', 'protein_10') got scores [0.19705666743448327, 0.23996533938044107]
# subset ('protein_2', 'protein_4', 'protein_8', 'protein_9', 'protein_10') got scores [0.19854463739440856, 0.16365905337779857]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_7', 'protein_8') got scores [0.17666852106411593, 0.13554050719709332]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_7', 'protein_9') got scores [0.17767261048182173, 0.11368199636126597]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_7', 'protein_10') got scores [0.17672200591735285, 0.15473077935380433]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_8', 'protein_9') got scores [0.17987349060452368, 0.12953124674516966]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_8', 'protein_10') got scores [0.17495423577228775, 0.11010539558387086]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_9', 'protein_10') got scores [0.17435204899449533, 0.17218984201215695]
# subset ('protein_2', 'protein_5', 'protein_7', 'protein_8', 'protein_9') got scores [0.16551551380087465, 0.13212163028236476]
# subset ('protein_2', 'protein_5', 'protein_7', 'protein_8', 'protein_10') got scores [0.1489876775873655, 0.12688469747990153]
# subset ('protein_2', 'protein_5', 'protein_7', 'protein_9', 'protein_10') got scores [0.16889019800925398, 0.14624172343464498]
# subset ('protein_2', 'protein_5', 'protein_8', 'protein_9', 'protein_10') got scores [0.1647173663619134, 0.12553619417032824]
# subset ('protein_2', 'protein_6', 'protein_7', 'protein_8', 'protein_9') got scores [0.15416307649452712, 0.13990038280561584]
# subset ('protein_2', 'protein_6', 'protein_7', 'protein_8', 'protein_10') got scores [0.13349890607001058, 0.17089284340953956]
# subset ('protein_2', 'protein_6', 'protein_7', 'protein_9', 'protein_10') got scores [0.16394073532067938, 0.11472039178684043]
# subset ('protein_2', 'protein_6', 'protein_8', 'protein_9', 'protein_10') got scores [0.16507779410698886, 0.11790124555165929]
# subset ('protein_2', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.07582799649720007, 0.2131542691050814]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_6', 'protein_7') got scores [0.24466318602786508, 0.21836919474205704]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_6', 'protein_8') got scores [0.2488000740719524, 0.21039067033718686]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_6', 'protein_9') got scores [0.25873648972702856, 0.21244807282482628]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_6', 'protein_10') got scores [0.24728392828587314, 0.21387271442151085]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_7', 'protein_8') got scores [0.2302982532621127, 0.20624249779788514]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_7', 'protein_9') got scores [0.238906681786125, 0.2249031252887561]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_7', 'protein_10') got scores [0.2191635471829184, 0.2107554464085968]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_8', 'protein_9') got scores [0.23955623694489858, 0.21338840055828714]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_8', 'protein_10') got scores [0.22982123265665316, 0.19934063016402012]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_9', 'protein_10') got scores [0.23856639964722842, 0.1893260719550714]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_7', 'protein_8') got scores [0.1839281025695655, 0.18580152275623188]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_7', 'protein_9') got scores [0.2110750031340619, 0.09813506013424249]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_7', 'protein_10') got scores [0.20273663155056212, 0.16882734753052162]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_8', 'protein_9') got scores [0.22124192354495656, 0.20097595991363343]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_8', 'protein_10') got scores [0.1941862453412405, 0.1310477763615236]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_9', 'protein_10') got scores [0.2170431972000629, 0.10264434533981054]
# subset ('protein_3', 'protein_4', 'protein_7', 'protein_8', 'protein_9') got scores [0.19079049370563542, 0.1619379889189009]
# subset ('protein_3', 'protein_4', 'protein_7', 'protein_8', 'protein_10') got scores [0.16227369430572516, 0.17296482583302558]
# subset ('protein_3', 'protein_4', 'protein_7', 'protein_9', 'protein_10') got scores [0.18909380247559884, 0.14679361364253488]
# subset ('protein_3', 'protein_4', 'protein_8', 'protein_9', 'protein_10') got scores [0.19341309205614393, 0.165133609707602]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_7', 'protein_8') got scores [0.16550834651567362, 0.05862985514607069]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_7', 'protein_9') got scores [0.16706194887840642, 0.15078956844394975]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_7', 'protein_10') got scores [0.152302795459724, 0.09099950210296148]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_8', 'protein_9') got scores [0.15978259146631063, 0.1718715195041107]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_8', 'protein_10') got scores [0.17063247243269247, 0.12669249205299984]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_9', 'protein_10') got scores [0.15748335797383925, 0.13596709540675803]
# subset ('protein_3', 'protein_5', 'protein_7', 'protein_8', 'protein_9') got scores [0.13544929548681636, 0.15571797079346145]
# subset ('protein_3', 'protein_5', 'protein_7', 'protein_8', 'protein_10') got scores [0.15097986065307026, 0.12588104326592225]
# subset ('protein_3', 'protein_5', 'protein_7', 'protein_9', 'protein_10') got scores [0.13370001335123458, 0.11921752640313257]
# subset ('protein_3', 'protein_5', 'protein_8', 'protein_9', 'protein_10') got scores [0.1326109546264989, 0.15568810280317413]
# subset ('protein_3', 'protein_6', 'protein_7', 'protein_8', 'protein_9') got scores [0.12855862959491057, 0.10518929568597103]
# subset ('protein_3', 'protein_6', 'protein_7', 'protein_8', 'protein_10') got scores [0.13554691656423912, 0.10512003239650924]
# subset ('protein_3', 'protein_6', 'protein_7', 'protein_9', 'protein_10') got scores [0.13019240703800364, 0.12362135619378677]
# subset ('protein_3', 'protein_6', 'protein_8', 'protein_9', 'protein_10') got scores [0.11313335830964952, 0.14303717937129012]
# subset ('protein_3', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.09350096218406244, 0.08774610532449821]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_7', 'protein_8') got scores [0.2467444756463724, 0.21608190353725365]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_7', 'protein_9') got scores [0.257381781309456, 0.23316767705271468]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_7', 'protein_10') got scores [0.2487401391622269, 0.21803068379730348]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_8', 'protein_9') got scores [0.2576494387863855, 0.23483816261182985]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_8', 'protein_10') got scores [0.2478070654744392, 0.21070121937305422]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_9', 'protein_10') got scores [0.257381781309456, 0.19954048894380025]
# subset ('protein_4', 'protein_5', 'protein_7', 'protein_8', 'protein_9') got scores [0.23703225361019195, 0.2193895808021202]
# subset ('protein_4', 'protein_5', 'protein_7', 'protein_8', 'protein_10') got scores [0.2272643431383618, 0.21246801163055776]
# subset ('protein_4', 'protein_5', 'protein_7', 'protein_9', 'protein_10') got scores [0.23656366765583464, 0.22497872430853819]
# subset ('protein_4', 'protein_5', 'protein_8', 'protein_9', 'protein_10') got scores [0.24092518435129115, 0.22587540372674178]
# subset ('protein_4', 'protein_6', 'protein_7', 'protein_8', 'protein_9') got scores [0.21807452363728752, 0.1921203491347024]
# subset ('protein_4', 'protein_6', 'protein_7', 'protein_8', 'protein_10') got scores [0.19266221481124912, 0.2065148755574268]
# subset ('protein_4', 'protein_6', 'protein_7', 'protein_9', 'protein_10') got scores [0.20818585006149, 0.19266734881179873]
# subset ('protein_4', 'protein_6', 'protein_8', 'protein_9', 'protein_10') got scores [0.21757186858285588, 0.15677712928231471]
# subset ('protein_4', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.18924286444605296, 0.15572126603749406]
# subset ('protein_5', 'protein_6', 'protein_7', 'protein_8', 'protein_9') got scores [0.15920757445621062, 0.08154664297530828]
# subset ('protein_5', 'protein_6', 'protein_7', 'protein_8', 'protein_10') got scores [0.16306972157533797, 0.12357075910599451]
# subset ('protein_5', 'protein_6', 'protein_7', 'protein_9', 'protein_10') got scores [0.15757671249363245, 0.13042425132021462]
# subset ('protein_5', 'protein_6', 'protein_8', 'protein_9', 'protein_10') got scores [0.1805695858258415, 0.16796457882809815]
# subset ('protein_5', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.12977201114637835, 0.08815379462493039]
# subset ('protein_6', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.13740649356055235, 0.1200475410095651]
# Iteration #1
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_5') got scores [0.23992350346790883, 0.2220514885569295]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_6') got scores [0.23975552314839377, 0.22595070853524216]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_7') got scores [0.18841369640495523, 0.20848339736884872]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_8') got scores [0.1865694406561689, 0.20981007253070919]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_9') got scores [0.1946500706722469, 0.21977242566213726]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_4', 'protein_10') got scores [0.16524437126955205, 0.1417445181214011]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_5', 'protein_6') got scores [0.17116337259706255, 0.1460596803415176]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_5', 'protein_7') got scores [0.16115402290945535, 0.13789039733154293]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_5', 'protein_8') got scores [0.15132684253147272, 0.14963099425448428]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_5', 'protein_9') got scores [0.16575959262981915, 0.11090682477795924]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_5', 'protein_10') got scores [0.16148270550790858, 0.1412879517705822]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_6', 'protein_7') got scores [0.10979544435321203, 0.1121703053529686]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_6', 'protein_8') got scores [0.10125477105925182, 0.11783714769445738]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_6', 'protein_9') got scores [0.15965703159778044, 0.16139631866694482]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_6', 'protein_10') got scores [0.09088816856486312, 0.17567781518091818]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_7', 'protein_8') got scores [0.1044027422881719, 0.05877393447689068]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_7', 'protein_9') got scores [0.10140239282566499, 0.2194426068994019]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_7', 'protein_10') got scores [0.08686941339140383, 0.1456154997412594]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_8', 'protein_9') got scores [0.09462152510593161, 0.20674145485520593]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_8', 'protein_10') got scores [0.10841231836985471, 0.17298544747379027]
# subset ('protein_1', 'protein_2', 'protein_3', 'protein_9', 'protein_10') got scores [0.48821939159859934, 0.1746378431365544]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_5', 'protein_6') got scores [0.25497237853226495, 0.21222271541588295]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_5', 'protein_7') got scores [0.23992350346790883, 0.21702171060051634]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_5', 'protein_8') got scores [0.2398159404366225, 0.22477673540785126]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_5', 'protein_9') got scores [0.2496033056401946, 0.22712605530161828]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_5', 'protein_10') got scores [0.2404674530986983, 0.22804078223833224]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_6', 'protein_7') got scores [0.23587590401377145, 0.21603781365287494]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_6', 'protein_8') got scores [0.235596299081978, 0.19321331448794818]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_6', 'protein_9') got scores [0.23105482106398312, 0.2102091335313585]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_6', 'protein_10') got scores [0.235272114508652, 0.20676617944198605]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_7', 'protein_8') got scores [0.17666020783190445, 0.2180873771806246]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_7', 'protein_9') got scores [0.1920698517697964, 0.22004486040476004]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_7', 'protein_10') got scores [0.1717576320430306, 0.20653009477209827]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_8', 'protein_9') got scores [0.24716991515251285, 0.22268774674900116]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_8', 'protein_10') got scores [0.1864259993548413, 0.1514798478631332]
# subset ('protein_1', 'protein_2', 'protein_4', 'protein_9', 'protein_10') got scores [0.24585335056323593, 0.1862118048967539]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_6', 'protein_7') got scores [0.17204162686931646, 0.12022340789333073]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_6', 'protein_8') got scores [0.17661396933451273, 0.15075112870239285]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_6', 'protein_9') got scores [0.18104103245781875, 0.14183978681977902]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_6', 'protein_10') got scores [0.17363532161378872, 0.14339089612192493]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_7', 'protein_8') got scores [0.1579824448027895, 0.1369877177376531]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_7', 'protein_9') got scores [0.1644517534801829, 0.13340449327380444]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_7', 'protein_10') got scores [0.1602953966800745, 0.12420948108089788]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_8', 'protein_9') got scores [0.16779665772565897, 0.1347629060293658]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_8', 'protein_10') got scores [0.1507085311344299, 0.12714845533636976]
# subset ('protein_1', 'protein_2', 'protein_5', 'protein_9', 'protein_10') got scores [0.16760506710694625, 0.15904509844018158]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_7', 'protein_8') got scores [0.13339375768597178, 0.13044850222081067]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_7', 'protein_9') got scores [0.15827019146638321, 0.23017543164706558]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_7', 'protein_10') got scores [0.13254775087119564, 0.11510594407721615]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_8', 'protein_9') got scores [0.16169816372879448, 0.15424201932622286]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_8', 'protein_10') got scores [0.15576995785611802, 0.1559239884349621]
# subset ('protein_1', 'protein_2', 'protein_6', 'protein_9', 'protein_10') got scores [0.16153915429926113, 0.11272017952725888]
# subset ('protein_1', 'protein_2', 'protein_7', 'protein_8', 'protein_9') got scores [0.08093495428277907, 0.0646036420621016]
# subset ('protein_1', 'protein_2', 'protein_7', 'protein_8', 'protein_10') got scores [0.0792695480303073, 0.04763598914205537]
# subset ('protein_1', 'protein_2', 'protein_7', 'protein_9', 'protein_10') got scores [0.09803421211023688, 0.19026253038019247]
# subset ('protein_1', 'protein_2', 'protein_8', 'protein_9', 'protein_10') got scores [0.10355362948574584, 0.1406565961517057]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_5', 'protein_6') got scores [0.24860124125264638, 0.20757895529332968]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_5', 'protein_7') got scores [0.2260391027207554, 0.19725937876977018]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_5', 'protein_8') got scores [0.23336950430095887, 0.1970210129082408]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_5', 'protein_9') got scores [0.23960064335658643, 0.2058125039629106]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_5', 'protein_10') got scores [0.22711047866108827, 0.2046424830521387]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_6', 'protein_7') got scores [0.20412722846392226, 0.1423716754894937]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_6', 'protein_8') got scores [0.20321755594528793, 0.19816278706608326]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_6', 'protein_9') got scores [0.2331003415373657, 0.19365443788481213]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_6', 'protein_10') got scores [0.21284890461375672, 0.19927885006523635]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_7', 'protein_8') got scores [0.1593190013865838, 0.18969340224352058]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_7', 'protein_9') got scores [0.18457480148211933, 0.1802286872259361]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_7', 'protein_10') got scores [0.1508117189067109, 0.13197783274558253]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_8', 'protein_9') got scores [0.18674506226393728, 0.1841875665668841]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_8', 'protein_10') got scores [0.17311790746463793, 0.17420050716088353]
# subset ('protein_1', 'protein_3', 'protein_4', 'protein_9', 'protein_10') got scores [0.17490719560755985, 0.21280719885631996]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_6', 'protein_7') got scores [0.16525103693408646, 0.15418457214555917]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_6', 'protein_8') got scores [0.17751025440219728, 0.11944981119423703]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_6', 'protein_9') got scores [0.15748523761591499, 0.13059889417061846]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_6', 'protein_10') got scores [0.16050908813587927, 0.13678559096540202]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_7', 'protein_8') got scores [0.14211871409994042, 0.1390377789354078]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_7', 'protein_9') got scores [0.15522437759810195, 0.13932111046977896]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_7', 'protein_10') got scores [0.14778393586765556, 0.1253962911842704]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_8', 'protein_9') got scores [0.14554327180569393, 0.12413136371978567]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_8', 'protein_10') got scores [0.14111449533921164, 0.1172201154105018]
# subset ('protein_1', 'protein_3', 'protein_5', 'protein_9', 'protein_10') got scores [0.15452839017956596, 0.12296359623771341]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_7', 'protein_8') got scores [0.11831690051698804, 0.11744776467312786]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_7', 'protein_9') got scores [0.12135892262737956, 0.11126517091218087]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_7', 'protein_10') got scores [0.11380958937503642, 0.10420500704390269]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_8', 'protein_9') got scores [0.11577524468200422, 0.16201546765805724]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_8', 'protein_10') got scores [0.08523561462614378, 0.1068556920819254]
# subset ('protein_1', 'protein_3', 'protein_6', 'protein_9', 'protein_10') got scores [0.10987563826675975, 0.17085210937159392]
# subset ('protein_1', 'protein_3', 'protein_7', 'protein_8', 'protein_9') got scores [0.1018555621431224, 0.07573166363356512]
# subset ('protein_1', 'protein_3', 'protein_7', 'protein_8', 'protein_10') got scores [0.06632158242563847, 0.04117917032241233]
# subset ('protein_1', 'protein_3', 'protein_7', 'protein_9', 'protein_10') got scores [0.10892110809444128, 0.10656266146035948]
# subset ('protein_1', 'protein_3', 'protein_8', 'protein_9', 'protein_10') got scores [0.1253960780799775, 0.1169424756843148]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_6', 'protein_7') got scores [0.2481724598445078, 0.22087692354154342]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_6', 'protein_8') got scores [0.2479612571262793, 0.214984968957071]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_6', 'protein_9') got scores [0.2553416287860282, 0.23479504473249346]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_6', 'protein_10') got scores [0.24822402591393983, 0.21249235251105486]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_7', 'protein_8') got scores [0.22996056830460634, 0.2083347696631057]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_7', 'protein_9') got scores [0.23702512434141385, 0.2172192053759519]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_7', 'protein_10') got scores [0.2212700671623793, 0.2100351978803816]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_8', 'protein_9') got scores [0.24202366114793816, 0.19724975655742963]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_8', 'protein_10') got scores [0.22980520912965258, 0.20712335774748722]
# subset ('protein_1', 'protein_4', 'protein_5', 'protein_9', 'protein_10') got scores [0.23415115418597737, 0.20967078475347956]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_7', 'protein_8') got scores [0.19111081574724284, 0.19997421906399526]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_7', 'protein_9') got scores [0.19874618746378758, 0.18925607789428367]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_7', 'protein_10') got scores [0.19189898173005948, 0.1434706752542099]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_8', 'protein_9') got scores [0.21274138195718945, 0.1969223199769092]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_8', 'protein_10') got scores [0.18920317946325974, 0.16839702153838887]
# subset ('protein_1', 'protein_4', 'protein_6', 'protein_9', 'protein_10') got scores [0.21013205571394114, 0.20615321936321157]
# subset ('protein_1', 'protein_4', 'protein_7', 'protein_8', 'protein_9') got scores [0.18797919826195267, 0.22150964700921028]
# subset ('protein_1', 'protein_4', 'protein_7', 'protein_8', 'protein_10') got scores [0.17787356361838977, 0.1642689312636201]
# subset ('protein_1', 'protein_4', 'protein_7', 'protein_9', 'protein_10') got scores [0.18530344849456762, 0.17717890264011088]
# subset ('protein_1', 'protein_4', 'protein_8', 'protein_9', 'protein_10') got scores [0.1886547574658872, 0.17655643665820409]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_7', 'protein_8') got scores [0.17346370196081318, 0.15416446326116248]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_7', 'protein_9') got scores [0.17078514269525577, 0.13066100691094878]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_7', 'protein_10') got scores [0.16784125564230798, 0.10083907228044134]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_8', 'protein_9') got scores [0.16139758772822307, 0.14979517872208398]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_8', 'protein_10') got scores [0.16827084872223322, 0.16628631855313578]
# subset ('protein_1', 'protein_5', 'protein_6', 'protein_9', 'protein_10') got scores [0.1608774825413151, 0.14272447585481438]
# subset ('protein_1', 'protein_5', 'protein_7', 'protein_8', 'protein_9') got scores [0.15257169257452735, 0.14266445832403993]
# subset ('protein_1', 'protein_5', 'protein_7', 'protein_8', 'protein_10') got scores [0.1296208293507173, 0.11759809635997054]
# subset ('protein_1', 'protein_5', 'protein_7', 'protein_9', 'protein_10') got scores [0.1574534812379113, 0.11258015236173574]
# subset ('protein_1', 'protein_5', 'protein_8', 'protein_9', 'protein_10') got scores [0.14719387916904436, 0.1411279796521676]
# subset ('protein_1', 'protein_6', 'protein_7', 'protein_8', 'protein_9') got scores [0.1258530683855096, 0.09378904066039928]
# subset ('protein_1', 'protein_6', 'protein_7', 'protein_8', 'protein_10') got scores [0.10904377744766712, 0.05999420229540483]
# subset ('protein_1', 'protein_6', 'protein_7', 'protein_9', 'protein_10') got scores [0.1256530824086384, 0.08836250932721175]
# subset ('protein_1', 'protein_6', 'protein_8', 'protein_9', 'protein_10') got scores [0.12534908149435503, 0.1251225869125905]
# ...
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_5', 'protein_7') got scores [0.24018447243066876, 0.22901682419566005]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_5', 'protein_8') got scores [0.2397006289315529, 0.22388260372273164]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_5', 'protein_9') got scores [0.24931509627517046, 0.22891301662460625]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_5', 'protein_10') got scores [0.24035976962084737, 0.22040787210710208]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_6', 'protein_7') got scores [0.23663303698290525, 0.18463416393801413]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_6', 'protein_8') got scores [0.23781516063045488, 0.2031251920556473]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_6', 'protein_9') got scores [0.24060246535129312, 0.19036237398164907]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_6', 'protein_10') got scores [0.23781516063045488, 0.20158995477389494]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_7', 'protein_8') got scores [0.18087724603787597, 0.2169780379405668]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_7', 'protein_9') got scores [0.19618964911025868, 0.20720872755473332]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_7', 'protein_10') got scores [0.17904251347038688, 0.21274987546865715]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_8', 'protein_9') got scores [0.24740006139842813, 0.23191352188729256]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_8', 'protein_10') got scores [0.1894181410037348, 0.1874023098017619]
# subset ('protein_2', 'protein_3', 'protein_4', 'protein_9', 'protein_10') got scores [0.24634261918952544, 0.17114898860618968]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_6', 'protein_7') got scores [0.17646387797570304, 0.11775838775054392]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_6', 'protein_8') got scores [0.17495423577228775, 0.14622672572870066]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_6', 'protein_9') got scores [0.17623877027477408, 0.16062108562141117]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_6', 'protein_10') got scores [0.1732487854808446, 0.1370199780757346]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_7', 'protein_8') got scores [0.1476039765702626, 0.1507963611953402]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_7', 'protein_9') got scores [0.1675006322705097, 0.12073519641400736]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_7', 'protein_10') got scores [0.1456660963773353, 0.10092278994541531]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_8', 'protein_9') got scores [0.1639830700150965, 0.11953721601042373]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_8', 'protein_10') got scores [0.16567624983010248, 0.1411490996750268]
# subset ('protein_2', 'protein_3', 'protein_5', 'protein_9', 'protein_10') got scores [0.16554071720642363, 0.10955078282394108]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_7', 'protein_8') got scores [0.12742907273992862, 0.09979161001921603]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_7', 'protein_9') got scores [0.16051519732849087, 0.2174728053618267]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_7', 'protein_10') got scores [0.13730011649243448, 0.11381373414290234]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_8', 'protein_9') got scores [0.16125284469368514, 0.1262130663218567]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_8', 'protein_10') got scores [0.10433816675614657, 0.15021567620264495]
# subset ('protein_2', 'protein_3', 'protein_6', 'protein_9', 'protein_10') got scores [0.1630692197807939, 0.19865258501459418]
# subset ('protein_2', 'protein_3', 'protein_7', 'protein_8', 'protein_9') got scores [0.35866962011576553, 0.08776568794018891]
# subset ('protein_2', 'protein_3', 'protein_7', 'protein_8', 'protein_10') got scores [0.06694179604603467, 0.1652991807880971]
# subset ('protein_2', 'protein_3', 'protein_7', 'protein_9', 'protein_10') got scores [0.3301754656307928, 0.07669826357406279]
# subset ('protein_2', 'protein_3', 'protein_8', 'protein_9', 'protein_10') got scores [0.2989889613291057, 0.07628323074804413]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_6', 'protein_7') got scores [0.2511753675356131, 0.22447268850345078]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_6', 'protein_8') got scores [0.2517787268068294, 0.22182048320689854]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_6', 'protein_9') got scores [0.25580114405986254, 0.21624629872364423]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_6', 'protein_10') got scores [0.25195836342213995, 0.21407787965753725]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_7', 'protein_8') got scores [0.2397006289315529, 0.21667482693757534]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_7', 'protein_9') got scores [0.24928658713380678, 0.23332649744664952]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_7', 'protein_10') got scores [0.24035976962084737, 0.2262983636027378]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_8', 'protein_9') got scores [0.25043544274849194, 0.23426597846053684]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_8', 'protein_10') got scores [0.24000184110884906, 0.21037296970369956]
# subset ('protein_2', 'protein_4', 'protein_5', 'protein_9', 'protein_10') got scores [0.24961389494079403, 0.22975145851797865]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_7', 'protein_8') got scores [0.23258783740751168, 0.1848146999463067]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_7', 'protein_9') got scores [0.22047768245160348, 0.2087361931827036]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_7', 'protein_10') got scores [0.2364182815031829, 0.19012852397011018]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_8', 'protein_9') got scores [0.23725212531945422, 0.2077494129066273]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_8', 'protein_10') got scores [0.23669732342358296, 0.2062882908611315]
# subset ('protein_2', 'protein_4', 'protein_6', 'protein_9', 'protein_10') got scores [0.23345632403658942, 0.23819543556431802]
# subset ('protein_2', 'protein_4', 'protein_7', 'protein_8', 'protein_9') got scores [0.2016550983521567, 0.20656210932528998]
# subset ('protein_2', 'protein_4', 'protein_7', 'protein_8', 'protein_10') got scores [0.18638516220067294, 0.1572186306135935]
# subset ('protein_2', 'protein_4', 'protein_7', 'protein_9', 'protein_10') got scores [0.19705666743448327, 0.23066582498088758]
# subset ('protein_2', 'protein_4', 'protein_8', 'protein_9', 'protein_10') got scores [0.19854463739440856, 0.22299977878365998]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_7', 'protein_8') got scores [0.17640745181726755, 0.15265225886137337]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_7', 'protein_9') got scores [0.1770070996315226, 0.1345264468343971]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_7', 'protein_10') got scores [0.17672200591735285, 0.1451989197002093]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_8', 'protein_9') got scores [0.18074878326438434, 0.136226561580409]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_8', 'protein_10') got scores [0.17495423577228775, 0.15391309899805963]
# subset ('protein_2', 'protein_5', 'protein_6', 'protein_9', 'protein_10') got scores [0.17876420223311681, 0.11324277157368363]
# subset ('protein_2', 'protein_5', 'protein_7', 'protein_8', 'protein_9') got scores [0.16449535049741543, 0.11161335825037959]
# subset ('protein_2', 'protein_5', 'protein_7', 'protein_8', 'protein_10') got scores [0.1489876775873655, 0.12688469747990153]
# subset ('protein_2', 'protein_5', 'protein_7', 'protein_9', 'protein_10') got scores [0.16782786152837428, 0.15459495625869202]
# subset ('protein_2', 'protein_5', 'protein_8', 'protein_9', 'protein_10') got scores [0.1647173663619134, 0.1082272370423322]
# subset ('protein_2', 'protein_6', 'protein_7', 'protein_8', 'protein_9') got scores [0.16868146627448044, 0.10311834260729788]
# subset ('protein_2', 'protein_6', 'protein_7', 'protein_8', 'protein_10') got scores [0.13349890607001058, 0.10951613540828106]
# subset ('protein_2', 'protein_6', 'protein_7', 'protein_9', 'protein_10') got scores [0.16380124377126998, 0.10751788946300993]
# subset ('protein_2', 'protein_6', 'protein_8', 'protein_9', 'protein_10') got scores [0.1656178442521403, 0.11790124555165929]
# subset ('protein_2', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.07463197924807785, 0.14642654287614656]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_6', 'protein_7') got scores [0.2434888481965302, 0.21836919474205704]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_6', 'protein_8') got scores [0.24840357238398408, 0.21039067033718686]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_6', 'protein_9') got scores [0.25873648972702856, 0.23765500948770776]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_6', 'protein_10') got scores [0.24728392828587314, 0.21442280347761478]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_7', 'protein_8') got scores [0.23170037754807277, 0.1954088082796297]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_7', 'protein_9') got scores [0.2391220893860553, 0.20018546920265798]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_7', 'protein_10') got scores [0.2198439728900128, 0.19444026166815595]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_8', 'protein_9') got scores [0.23882837450126806, 0.21860240801767966]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_8', 'protein_10') got scores [0.22982123265665316, 0.21096668515386935]
# subset ('protein_3', 'protein_4', 'protein_5', 'protein_9', 'protein_10') got scores [0.2393703611014434, 0.20228882844639604]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_7', 'protein_8') got scores [0.18402417924820844, 0.18233817327324034]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_7', 'protein_9') got scores [0.2099457090240329, 0.18983838705466388]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_7', 'protein_10') got scores [0.20361310981290898, 0.19497418191837843]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_8', 'protein_9') got scores [0.22124192354495656, 0.21585234192717456]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_8', 'protein_10') got scores [0.1963490095176492, 0.21290680591418462]
# subset ('protein_3', 'protein_4', 'protein_6', 'protein_9', 'protein_10') got scores [0.2170431972000629, 0.18732412112508876]
# subset ('protein_3', 'protein_4', 'protein_7', 'protein_8', 'protein_9') got scores [0.19077886324994633, 0.1679298621700028]
# subset ('protein_3', 'protein_4', 'protein_7', 'protein_8', 'protein_10') got scores [0.16128432011569735, 0.17532122117225665]
# subset ('protein_3', 'protein_4', 'protein_7', 'protein_9', 'protein_10') got scores [0.19173205389486858, 0.1509417705667027]
# subset ('protein_3', 'protein_4', 'protein_8', 'protein_9', 'protein_10') got scores [0.19231917004854354, 0.19157667689024468]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_7', 'protein_8') got scores [0.15804177868282368, 0.07764385503338415]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_7', 'protein_9') got scores [0.16723931299533945, 0.15119651380368512]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_7', 'protein_10') got scores [0.15288412993691805, 0.09099950210296148]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_8', 'protein_9') got scores [0.1757994573250828, 0.1675046670898126]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_8', 'protein_10') got scores [0.16993980749325693, 0.06226361547931458]
# subset ('protein_3', 'protein_5', 'protein_6', 'protein_9', 'protein_10') got scores [0.15741313153382092, 0.12020815595432519]
# subset ('protein_3', 'protein_5', 'protein_7', 'protein_8', 'protein_9') got scores [0.13402276935355303, 0.15116970946143693]
# subset ('protein_3', 'protein_5', 'protein_7', 'protein_8', 'protein_10') got scores [0.14849373629885185, 0.10144001288635679]
# subset ('protein_3', 'protein_5', 'protein_7', 'protein_9', 'protein_10') got scores [0.13370001335123458, 0.09510966409133534]
# subset ('protein_3', 'protein_5', 'protein_8', 'protein_9', 'protein_10') got scores [0.13215085722244954, 0.14923088400103932]
# subset ('protein_3', 'protein_6', 'protein_7', 'protein_8', 'protein_9') got scores [0.12983745342250666, 0.10388199748599036]
# subset ('protein_3', 'protein_6', 'protein_7', 'protein_8', 'protein_10') got scores [0.13432855076552222, 0.11280334688249564]
# subset ('protein_3', 'protein_6', 'protein_7', 'protein_9', 'protein_10') got scores [0.1345499894416221, 0.12093663932242582]
# subset ('protein_3', 'protein_6', 'protein_8', 'protein_9', 'protein_10') got scores [0.11569088605220981, 0.12016686316457259]
# subset ('protein_3', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.09350096218406244, 0.06500536729880198]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_7', 'protein_8') got scores [0.24198311074284082, 0.22696678382468852]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_7', 'protein_9') got scores [0.2574861441028695, 0.23378374845008826]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_7', 'protein_10') got scores [0.2487401391622269, 0.2252589797808496]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_8', 'protein_9') got scores [0.2576494387863855, 0.21440726789611247]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_8', 'protein_10') got scores [0.24793655111816637, 0.2103338785855879]
# subset ('protein_4', 'protein_5', 'protein_6', 'protein_9', 'protein_10') got scores [0.257381781309456, 0.22016010626958243]
# subset ('protein_4', 'protein_5', 'protein_7', 'protein_8', 'protein_9') got scores [0.23703225361019195, 0.19475614485291345]
# subset ('protein_4', 'protein_5', 'protein_7', 'protein_8', 'protein_10') got scores [0.22783580726518476, 0.2179047749005198]
# subset ('protein_4', 'protein_5', 'protein_7', 'protein_9', 'protein_10') got scores [0.23228085393391065, 0.2394220345430212]
# subset ('protein_4', 'protein_5', 'protein_8', 'protein_9', 'protein_10') got scores [0.24197405092255508, 0.2323637738463221]
# subset ('protein_4', 'protein_6', 'protein_7', 'protein_8', 'protein_9') got scores [0.21509334233974123, 0.1921203491347024]
# subset ('protein_4', 'protein_6', 'protein_7', 'protein_8', 'protein_10') got scores [0.19266221481124912, 0.20970558570630307]
# subset ('protein_4', 'protein_6', 'protein_7', 'protein_9', 'protein_10') got scores [0.20818585006149, 0.18864553392101144]
# subset ('protein_4', 'protein_6', 'protein_8', 'protein_9', 'protein_10') got scores [0.21757186858285588, 0.20280343980559085]
# subset ('protein_4', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.1898897662557451, 0.17283188248595663]
# subset ('protein_5', 'protein_6', 'protein_7', 'protein_8', 'protein_9') got scores [0.15920757445621062, 0.12032272772156108]
# subset ('protein_5', 'protein_6', 'protein_7', 'protein_8', 'protein_10') got scores [0.16376242020039888, 0.1030889944353334]
# subset ('protein_5', 'protein_6', 'protein_7', 'protein_9', 'protein_10') got scores [0.1773804495066904, 0.1291175322671964]
# subset ('protein_5', 'protein_6', 'protein_8', 'protein_9', 'protein_10') got scores [0.16018840357307587, 0.16783187947283656]
# subset ('protein_5', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.12977201114637835, 0.10426364600339597]
# subset ('protein_6', 'protein_7', 'protein_8', 'protein_9', 'protein_10') got scores [0.13834524551038577, 0.09009586057102659]

# %% [markdown]
# ## Using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=5, random_state=0)
clf.fit(df, kmeans.predict(df))
importance = pd.DataFrame(clf.feature_importances_)
importance.index = np.arange(1, len(importance) + 1)
print(importance[0].nlargest(5).index.to_numpy())
# Out:
# [4 5 6 8 9]

# %% [markdown]
# ## Using PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=5)

df_hat = pca.fit_transform(df)

importance = pd.DataFrame(abs( pca.components_ ))

f = np.ndarray(shape=(5,1), dtype=np.int8)
for i in range(5):
    best_feat = importance.T[i].argmax()
    importance[best_feat] = 0
    f[i] = best_feat

f = f + 1
print(f.flatten())
# Out:
# [4 2 6 5 9]

# %% [markdown]
# # Selected 5 best features
#
# We shall use the set produced by the RandomForest method

# %%
selected_features = [f'protein_{i}' for i in [4, 5, 6, 8, 9]]

kmeans = KMeans(n_clusters=5, max_iter=500, n_init=30)
selected_model = kmeans.fit(df[selected_features])

# %% [markdown]
# ## Save results

# %%
result = pd.DataFrame()
result['ID'] = id_col
result['y'] = selected_model.labels_

result.to_csv(f'results/clusters.csv', index=False)

# %% [markdown]
# # Visualizations

# %%
from sklearn.decomposition import PCA
# %matplotlib qt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn.manifold import TSNE


def reduce_dims_tsne_2d(X, y):
    tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
    tsne_results = tsne.fit_transform(X)
        
    df_subset = pd.DataFrame()
    df_subset['tsne-2d-one'] = tsne_results[:,0]
    df_subset['tsne-2d-two'] = tsne_results[:,1]
    df_subset['y'] = y
    
    plt.figure(figsize=(16,10))
    sns.scatterplot(
        x="tsne-2d-one", y="tsne-2d-two",
        hue="y",
        palette=sns.color_palette("hls", 5),
        data=df_subset,
        legend="full"
    )
    
def reduce_dims_tsne_3d(X, y):
    tsne = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=300)
    tsne_results = tsne.fit_transform(X)
    
    df_subset = pd.DataFrame()
    df_subset['tsne-3d-one'] = tsne_results[:,0]
    df_subset['tsne-3d-two'] = tsne_results[:,1]
    df_subset['tsne-3d-three'] = tsne_results[:,2]
    df_subset['y'] = y
    
    ax = plt.figure(figsize=(16,10)).gca(projection='3d')
    ax.scatter(
        xs=df_subset["tsne-3d-one"], 
        ys=df_subset["tsne-3d-two"], 
        zs=df_subset["tsne-3d-three"], 
        c=df_subset["y"], 
        cmap='tab10'
    )

def reduce_dims_and_plot_2d(X, y, centers):
    

    pca = PCA(n_components=3)

    X_hat = pca.fit_transform(X)

    centers_hat = pca.transform(centers)

    reduced = pd.DataFrame()
    reduced['pca-one'] = X_hat[:,0]
    reduced['pca-two'] = X_hat[:,1]
    reduced['pca-three'] = X_hat[:,2]
    reduced['y'] = y

    centers_reduced = pd.DataFrame()
    centers_reduced['pca-one'] = centers_hat[:,0]
    centers_reduced['pca-two'] = centers_hat[:,1]
    centers_reduced['pca-three'] = centers_hat[:,2]

    plt.figure(figsize=(16,10))
    sns.scatterplot(
        x="pca-one", y="pca-two",
        hue="y",
        palette="deep",
        data=reduced,
        legend="full",
    )
    plt.scatter(centers_reduced['pca-one'], centers_reduced['pca-two'], marker='o',
                c="white", alpha=1, s=200, edgecolor='k'
    )

def reduce_dims_and_plot_3d(X, y, centers):
    reduced = pd.DataFrame()

    pca = PCA(n_components=3)

    X_hat = pca.fit_transform(X)

    centers_hat = pca.transform(centers)

    reduced['pca-one'] = X_hat[:,0]
    reduced['pca-two'] = X_hat[:,1]
    reduced['pca-three'] = X_hat[:,2]
    reduced['y'] = y

    centers_reduced = pd.DataFrame()
    centers_reduced['pca-one'] = centers_hat[:,0]
    centers_reduced['pca-two'] = centers_hat[:,1]
    centers_reduced['pca-three'] = centers_hat[:,2]

    ax = plt.figure(figsize=(16,10)).gca(projection='3d')
    ax.scatter(
        xs=reduced["pca-one"], 
        ys=reduced["pca-two"], 
        zs=reduced["pca-three"], 
        c=reduced["y"], 
        cmap='tab10'
    )
    ax.scatter(
        xs=centers_reduced["pca-one"], 
        ys=centers_reduced["pca-two"], 
        zs=centers_reduced["pca-three"],
        marker='o', c="white", alpha=1, s=200, edgecolor='k'
    )
    ax.set_xlabel('pca-one')
    ax.set_ylabel('pca-two')
    ax.set_zlabel('pca-three')
    plt.show()

# %%
from sklearn.neighbors import NearestCentroid

kmeans_centroids_clf = NearestCentroid()
kmeans_centroids_clf.fit(df, selected_model.predict(df[selected_features]))
kmeans_centroids = kmeans_centroids_clf.centroids_

# %%
reduce_dims_tsne_2d(df, selected_model.labels_)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 494 samples in 0.000s...
# [t-SNE] Computed neighbors for 494 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 494 / 494
# [t-SNE] Mean sigma: 1.915300
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.918018
# [t-SNE] KL divergence after 300 iterations: 0.430078

# %%
reduce_dims_tsne_3d(df, kmeans.labels_)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 494 samples in 0.001s...
# [t-SNE] Computed neighbors for 494 samples in 0.017s...
# [t-SNE] Computed conditional probabilities for sample 494 / 494
# [t-SNE] Mean sigma: 1.917716
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 88.412491
# [t-SNE] KL divergence after 300 iterations: 2.303170

# %% [markdown]
# # Mutations Characteristics

# %% [markdown]
# ## Mutation Prevelence

# %%
df_labeled = pd.DataFrame(df)
df_labeled['y'] = kmeans.labels_
df_labeled.y.value_counts(normalize=True)
# Out:
# 4    0.267206
# 0    0.257085
# 1    0.176113
# 3    0.163968
# 2    0.135628
# Name: y, dtype: float64

# %% [markdown]
# ## Mutation Centroids

# %%
kmeans_centroids
# Out:
# array([[-0.3128214 , -0.20425036, -0.14244392,  2.01640322,  3.10960182,
#         -1.30064473, -0.19273014, -0.55392528,  0.75671846, -0.28953301,
#          1.78740157],
#        [ 0.16330108, -0.43780059,  0.32144023, -2.50828214,  0.99670679,
#          1.88562052, -0.06453814,  0.667714  , -0.85334941, -0.27501847,
#          1.64367816],
#        [-0.27794711,  0.21071739,  0.06361202,  1.9751433 , -2.28320876,
#          3.33977166,  0.14758316, -0.86933961,  0.85004889,  0.34351594,
#          1.68656716],
#        [-0.46006078,  0.12161429,  0.2379126 , -3.15692522, -1.50542254,
#         -2.34719029,  0.15988659, -0.28984255,  0.7867914 , -0.1806468 ,
#          1.86419753],
#        [ 0.19353935, -0.3637506 , -0.04926919,  4.59336164, -1.26035494,
#         -0.87746539,  0.26796543,  0.54032077, -1.48251359,  0.52352467,
#          1.26515152]])

# %% [markdown]
# ## Nearest neighbour

# %%
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=5).fit(kmeans_centroids)
distances, indices = nbrs.kneighbors(kmeans_centroids)

print(distances)
# Out:
# [[0.         5.79348112 6.30141551 7.04572986 7.17414627]
#  [0.         5.38715657 6.27286023 6.30141551 8.03801765]
#  [0.         5.82270701 6.27286023 7.17414627 7.74611963]
#  [0.         5.38715657 7.04572986 7.74611963 8.35090727]
#  [0.         5.79348112 5.82270701 8.03801765 8.35090727]]
